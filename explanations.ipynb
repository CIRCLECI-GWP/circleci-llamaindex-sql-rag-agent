# %%
# Import core packages
import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()

# %% [markdown]
# ## 2. Create a database

# %%
# db_creator.py

import json
import sqlalchemy as sa
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker

# Create the base class for our models
Base = declarative_base()

# Define our State model
class State(Base):
    __tablename__ = 'states'
    
    id = sa.Column(sa.Integer, primary_key=True)
    object_id = sa.Column(sa.String(50), unique=True)
    name = sa.Column(sa.String(50), unique=True, nullable=False)
    flag_url = sa.Column(sa.String(255))
    link = sa.Column(sa.String(100))
    postal_abbreviation = sa.Column(sa.String(2), unique=True)
    capital = sa.Column(sa.String(50))
    largest_city = sa.Column(sa.String(50))
    established = sa.Column(sa.String(50))
    population = sa.Column(sa.Integer)
    total_area_square_miles = sa.Column(sa.Integer)
    total_area_square_kilometers = sa.Column(sa.Integer)
    land_area_square_miles = sa.Column(sa.Integer)
    land_area_square_kilometers = sa.Column(sa.Integer)
    water_area_square_miles = sa.Column(sa.Integer)
    water_area_square_kilometers = sa.Column(sa.Integer)
    number_representatives = sa.Column(sa.Integer)
    created_at = sa.Column(sa.String(100))
    updated_at = sa.Column(sa.String(100))
    capitals_object_id = sa.Column(sa.String(50))

def main():
    # Connect to the database
    engine = sa.create_engine('sqlite:///states.db', echo=True)
    
    # Create tables
    Base.metadata.create_all(engine)
    
    # Create a session
    Session = sessionmaker(bind=engine)
    session = Session()
    
    # Load the JSON data
    with open('states.json', 'r') as f:
        data = json.load(f)
        states_data = data.get('results', [])
    
    # Insert data
    for state_data in states_data:
        # Create a new State object
        state = State(
            object_id=state_data.get('objectId'),
            name=state_data.get('name'),
            flag_url=state_data.get('flag'),
            link=state_data.get('link'),
            postal_abbreviation=state_data.get('postalAbreviation'),
            capital=state_data.get('capital'),
            largest_city=state_data.get('largestCity'),
            established=state_data.get('established'),
            population=state_data.get('population'),
            total_area_square_miles=state_data.get('totalAreaSquareMiles'),
            total_area_square_kilometers=state_data.get('totalAreaSquareKilometers'),
            land_area_square_miles=state_data.get('landAreaSquareMiles'),
            land_area_square_kilometers=state_data.get('landAreaSquareKilometers'),
            water_area_square_miles=state_data.get('waterAreaSquareMiles'),
            water_area_square_kilometers=state_data.get('waterAreaSquareKilometers'),
            number_representatives=state_data.get('numberRepresentatives'),
            created_at=state_data.get('createdAt'),
            updated_at=state_data.get('updatedAt')
        )
        
        # Handle the capitals pointer
        if 'capitals' in state_data and isinstance(state_data['capitals'], dict):
            state.capitals_object_id = state_data['capitals'].get('objectId')
        
        # Add to session
        session.add(state)
    
    # Commit the session
    try:
        session.commit()
        print(f"Successfully imported {len(states_data)} states to the database.")
    except Exception as e:
        session.rollback()
        print(f"Error: Failed to commit data to database. {e}")
    finally:
        session.close()

if __name__ == "__main__":
    main()

# %%
# Test if db was created and populated correctly
import sqlalchemy as sa
from sqlalchemy.ext.declarative import declarative_base
from sqlalchemy.orm import sessionmaker
from sqlalchemy import inspect
from db_creator import State
def test_database():
    """Test if the database was created and populated correctly."""
    print("\n----- TESTING DATABASE -----")
    
    # Connect to the database
    engine = sa.create_engine('sqlite:///states.db')
    Session = sessionmaker(bind=engine)
    session = Session()
    
    try:
        # Check if the table exists
        inspector = inspect(session.bind)
        tables = inspector.get_table_names()
        print(f"Tables in database: {tables}")
        
        if 'states' not in tables:
            print("Error: 'states' table not found in database!")
            return
        
        # Count total records
        state_count = session.query(State).count()
        print(f"Total states in database: {state_count}")
        
        # Check a few specific states
        print("\nSample state data:")
        sample_states = ['Alabama', 'Alaska', 'Wyoming']
        for state_name in sample_states:
            state = session.query(State).filter_by(name=state_name).first()
            if state:
                print(f"- {state.name}: Capital: {state.capital}, Population: {state.population}")
            else:
                print(f"- {state_name}: Not found in database!")
        
        # Show schema details
        print("\nTable columns:")
        for column in inspector.get_columns('states'):
            print(f"- {column['name']}: {column['type']}")
            
        # Run some additional queries
        print("\nStates with population over 5 million:")
        populous_states = session.query(State).filter(State.population > 5000000).all()
        for state in populous_states:
            print(f"{state.name}: {state.population}")
            
        print("\nStates with largest city same as capital:")
        capital_largest = session.query(State).filter(State.capital == State.largest_city).all()
        for state in capital_largest:
            print(f"{state.name}: {state.capital}")
    
    finally:
        session.close()

# %%
test_database()
# Out:
# ----- TESTING DATABASE -----
# Tables in database: ['states']
# Total states in database: 50
#
# Sample state data:
# - Alabama: Capital: Montgomery, Population: 4874747
# - Alaska: Capital: Juneau, Population: 739795
# - Wyoming: Capital: Cheyenne, Population: 579315
#
# Table columns:
# - id: INTEGER
# - object_id: VARCHAR(50)
# - name: VARCHAR(50)
# - flag_url: VARCHAR(255)
# - link: VARCHAR(100)
# - postal_abbreviation: VARCHAR(2)
# - capital: VARCHAR(50)
# - largest_city: VARCHAR(50)
# - established: VARCHAR(50)
# - population: INTEGER
# - total_area_square_miles: INTEGER
# - total_area_square_kilometers: INTEGER
# - land_area_square_miles: INTEGER
# - land_area_square_kilometers: INTEGER
# - water_area_square_miles: INTEGER
# - water_area_square_kilometers: INTEGER
# - number_representatives: INTEGER
# - created_at: VARCHAR(100)
# - updated_at: VARCHAR(100)
# - capitals_object_id: VARCHAR(50)
#
# States with population over 5 million:
# Arizona: 7016270
# California: 39536653
# Colorado: 5607154
# Florida: 20984400
# Georgia: 10429379
# Illinois: 12802023
# Indiana: 6666818
# Maryland: 6052177
# Massachusetts: 6859819
# Michigan: 9962311
# Minnesota: 5576606
# Missouri: 6113532
# New Jersey: 9005644
# New York: 19849399
# North Carolina: 10273419
# Ohio: 11658609
# Pennsylvania: 12805537
# South Carolina: 5024369
# Tennessee: 6715984
# Texas: 28304596
# Virginia: 8470020
# Washington: 7405743
# Wisconsin: 5795483
#
# States with largest city same as capital:
# Arizona: Phoenix
# Arkansas: Little Rock
# Colorado: Denver
# Georgia: Atlanta
# Hawaii: Honolulu
# Idaho: Boise
# Indiana: Indianapolis
# Iowa: Des Moines
# Massachusetts: Boston
# Mississippi: Jackson
# Ohio: Columbus
# Oklahoma: Oklahoma City
# Rhode Island: Providence
# Tennessee: Nashville
# Utah: Salt Lake City
# West Virginia: Charleston
# Wyoming: Cheyenne

# %% [markdown]
# ## 3. Enable Searching of SQL engine in plain english

# %%
# Create sql engine 
import sqlalchemy as sa

from llama_index.core.query_engine import NLSQLTableQueryEngine
from llama_index.core import SQLDatabase, Settings
from llama_index.llms.google_genai import GoogleGenAI

import os
from dotenv import load_dotenv

# Load environment variables
load_dotenv()


# Initialize LLM
llm = GoogleGenAI(
    model="models/gemini-2.5-pro-exp-03-25", 
    google_api_key=os.getenv("GOOGLE_API_KEY"),
    temperature=0.3
)
Settings.llm = llm

# Connect to the database
engine = sa.create_engine('sqlite:///states.db', future=True)


# Create the SQL database wrapper
sql_database = SQLDatabase(engine, include_tables=["states"])

# Generate sample data description to help the LLM understand the data structure
# This creates better context for the NLSQLTableQueryEngine
table_schema_str = """
Database Schema:
- states table:
  - object_id: Object ID like 
  - name: State name (e.g., "California", "Texas")
  - flag_url: link to states flag png image
  - link: url link to states page
  - postal_abbreviation: Two-letter state code (e.g., "CA", "TX")
  - capital: Capital city name
  - largest_city: name of largest city
  - established: date when state was established
  - population: state's population
  - total_area_square_miles= state total area in square miles
  - total_area_square_kilometers: total area in square kilometers
  - land_area_square_miles: land area in square miles
  - land_area_square_kilometers: land area in square kilometers
  - water_area_square_miles: water area in square miles
  - water_area_square_kilometers: water area in square kilometers
  - number_representatives: number of representatives
  - created_at: date of database creation
  - updated_at: date of database update
"""

# Create the natural language to SQL query engine with more context
sql_query_engine = NLSQLTableQueryEngine(
    sql_database=sql_database,
    tables=["states"],
    sample_rows_in_table_info=2,  # Include sample rows to provide better context
    llm=llm,
    embed_model=llm,
    synthesize_response=True,
    table_schema_str=table_schema_str,
    verbose=True  # This enables debug output to see the generated SQL
)

# %% [markdown]
# ### Test query engine

# %%
# Test sql engine  
import sqlalchemy as sa
from sqlalchemy.orm import sessionmaker 
from sqlalchemy import inspect

from llama_index.core.query_engine import NLSQLTableQueryEngine
from llama_index.core import SQLDatabase, Settings
from llama_index.llms.google_genai import GoogleGenAI 

import os
from dotenv import load_dotenv 

# Load environment variables
load_dotenv()

print("Step 1: Checking environment variables...")
google_api_key = os.getenv("GOOGLE_API_KEY")
if not google_api_key:
    print("ERROR: GOOGLE_API_KEY not found in environment variables")
else:
    print("✓ GOOGLE_API_KEY found")

print("\nStep 2: Initializing LLM...")
try:
    llm = GoogleGenAI(    
        model="models/gemini-2.5-exp-pro-03-25",     
        google_api_key=google_api_key,    
        temperature=0.3
    )
    Settings.llm = llm
    print("✓ LLM initialized successfully")
except Exception as e:
    print(f"ERROR initializing LLM: {e}")

print("\nStep 3: Connecting to database...")
try:
    engine = sa.create_engine('sqlite:///states.db', future=True)
    # Test the connection
    connection = engine.connect()
    connection.close()
    print("✓ Database connection successful")
    
    # Check if the 'states' table exists
    inspector = inspect(engine)
    if 'states' in inspector.get_table_names():
        print("✓ 'states' table found in database")
    else:
        print("ERROR: 'states' table not found in database")
        print(f"Available tables: {inspector.get_table_names()}")
except Exception as e:
    print(f"ERROR connecting to database: {e}")

print("\nStep 4: Creating SQL database wrapper...")
try:
    sql_database = SQLDatabase(engine, include_tables=["states"])
    print("✓ SQL database wrapper created")
    print(f"Tables included: {sql_database.get_usable_table_names()}")
except Exception as e:
    print(f"ERROR creating SQL database wrapper: {e}")

print("\nStep 5: Creating query engine...")
try:
    sql_query_engine = NLSQLTableQueryEngine(    
        sql_database=sql_database,    
        llm=llm,
        embed_model=llm,
        tables=["states"]
    )
    print("✓ Query engine created successfully")
except Exception as e:
    print(f"ERROR creating query engine: {e}")
    import traceback
    traceback.print_exc()

print("\nStep 6: Testing a simple query...")
if 'sql_query_engine' in locals():
    try:
        # Try with a very simple query first
        simple_query = "SELECT * FROM states LIMIT 5"
        print(f"Executing direct SQL query: {simple_query}")
        direct_results = sql_database.run_sql(simple_query)
        print(f"Direct SQL results: {direct_results[:100]}...")  # Print first 100 chars
        
        # Now try the natural language query
        nl_query = "What are the five most populous states?"
        print(f"Executing natural language query: {nl_query}")
        response = sql_query_engine.query(nl_query)
        print(f"Response type: {type(response)}")
        print(f"Response content: {response}")
    except Exception as e:
        print(f"ERROR executing query: {e}")
        import traceback
        traceback.print_exc()
# Out:
# Step 1: Checking environment variables...
# ✓ GOOGLE_API_KEY found
#
# Step 2: Initializing LLM...
# ERROR initializing LLM: [Errno 11001] getaddrinfo failed
#
# Step 3: Connecting to database...
# ✓ Database connection successful
# ✓ 'states' table found in database
#
# Step 4: Creating SQL database wrapper...
# ✓ SQL database wrapper created
# Tables included: ['states']
#
# Step 5: Creating query engine...
# ✓ Query engine created successfully
#
# Step 6: Testing a simple query...
# Executing direct SQL query: SELECT * FROM states LIMIT 5
# Direct SQL results: ("[(1, 'B9IfALchYP', 'Alabama', 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Flag_of_Alabama.svg/23px-Flag_of_Alabama.svg.png', '/wiki/Alabama', 'AL', 'Montgomery', 'Birmingham', 'Dec 14, 1819', 4874747, 52420, 135767, 50645, 131171, 1775, 4597, 7, '2019-12-06T19:36:50.117Z', '2019-12-09T23:20:36.439Z', 't0wuThlqBx'), (2, 'zq8GVoD1n0', 'Alaska', 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/e6/Flag_of_Alaska.svg/21px-Flag_of_Alaska.svg.png', '/wiki/Alaska', 'AK', 'Juneau', 'Anchorage', 'Jan 3, 1959', 739795, 665384, 1723337, 570641, 1477953, 94743, 245384, 1, '2019-12-06T19:36:50.597Z', '2019-12-09T23:20:25.520Z', 'xknNfY6ZcD'), (3, '9DhrhBxbKN', 'Arizona', 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Flag_of_Arizona.svg/23px-Flag_of_Arizona.svg.png', '/wiki/Arizona', 'AZ', 'Phoenix', 'Phoenix', 'Feb 14, 1912', 7016270, 113990, 295234, 113594, 294207, 396, 1026, 9, '2019-12-06T19:36:50.877Z', '2019-12-09T23:18:34.311Z', '5vGAgNr4C8'), (4, 'UGNHGooffs', 'Arkansas', 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Flag_of_Arkansas.svg/23px-Flag_of_Arkansas.svg.png', '/wiki/Arkansas', 'AR', 'Little Rock', 'Little Rock', 'Jun 15, 1836', 3004279, 53179, 137732, 52035, 134771, 1143, 2961, 4, '2019-12-06T19:36:51.153Z', '2019-12-09T23:16:24.718Z', 'BaNFmSEwrN'), (5, 'ta1PtZdnvM', 'California', 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/01/Flag_of_California.svg/23px-Flag_of_California.svg.png', '/wiki/California', 'CA', 'Sacramento', 'Los Angeles', 'Sep 9, 1850', 39536653, 163695, 423967, 155779, 403466, 7916, 20501, 53, '2019-12-06T19:36:51.430Z', '2019-12-09T23:20:09.986Z', 'MvNSUoM9Cq')]", {'result': [(1, 'B9IfALchYP', 'Alabama', 'https://upload.wikimedia.org/wikipedia/commons/thumb/5/5c/Flag_of_Alabama.svg/23px-Flag_of_Alabama.svg.png', '/wiki/Alabama', 'AL', 'Montgomery', 'Birmingham', 'Dec 14, 1819', 4874747, 52420, 135767, 50645, 131171, 1775, 4597, 7, '2019-12-06T19:36:50.117Z', '2019-12-09T23:20:36.439Z', 't0wuThlqBx'), (2, 'zq8GVoD1n0', 'Alaska', 'https://upload.wikimedia.org/wikipedia/commons/thumb/e/e6/Flag_of_Alaska.svg/21px-Flag_of_Alaska.svg.png', '/wiki/Alaska', 'AK', 'Juneau', 'Anchorage', 'Jan 3, 1959', 739795, 665384, 1723337, 570641, 1477953, 94743, 245384, 1, '2019-12-06T19:36:50.597Z', '2019-12-09T23:20:25.520Z', 'xknNfY6ZcD'), (3, '9DhrhBxbKN', 'Arizona', 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Flag_of_Arizona.svg/23px-Flag_of_Arizona.svg.png', '/wiki/Arizona', 'AZ', 'Phoenix', 'Phoenix', 'Feb 14, 1912', 7016270, 113990, 295234, 113594, 294207, 396, 1026, 9, '2019-12-06T19:36:50.877Z', '2019-12-09T23:18:34.311Z', '5vGAgNr4C8'), (4, 'UGNHGooffs', 'Arkansas', 'https://upload.wikimedia.org/wikipedia/commons/thumb/9/9d/Flag_of_Arkansas.svg/23px-Flag_of_Arkansas.svg.png', '/wiki/Arkansas', 'AR', 'Little Rock', 'Little Rock', 'Jun 15, 1836', 3004279, 53179, 137732, 52035, 134771, 1143, 2961, 4, '2019-12-06T19:36:51.153Z', '2019-12-09T23:16:24.718Z', 'BaNFmSEwrN'), (5, 'ta1PtZdnvM', 'California', 'https://upload.wikimedia.org/wikipedia/commons/thumb/0/01/Flag_of_California.svg/23px-Flag_of_California.svg.png', '/wiki/California', 'CA', 'Sacramento', 'Los Angeles', 'Sep 9, 1850', 39536653, 163695, 423967, 155779, 403466, 7916, 20501, 53, '2019-12-06T19:36:51.430Z', '2019-12-09T23:20:09.986Z', 'MvNSUoM9Cq')], 'col_keys': ['id', 'object_id', 'name', 'flag_url', 'link', 'postal_abbreviation', 'capital', 'largest_city', 'established', 'population', 'total_area_square_miles', 'total_area_square_kilometers', 'land_area_square_miles', 'land_area_square_kilometers', 'water_area_square_miles', 'water_area_square_kilometers', 'number_representatives', 'created_at', 'updated_at', 'capitals_object_id']})...

# %% [markdown]
# ## Setting up LlamaCloud

# %%
from llama_index.indices.managed.llama_cloud import LlamaCloudIndex

# Initialize the LlamaCloud index
index = LlamaCloudIndex(
    name="US-States-Wiki",
    project_name="sql_rag",
    organization_id=os.getenv("LLAMA_CLOUD_ORG_ID"),
    api_key=os.getenv("LLAMA_CLOUD_API_KEY")
)
# Create a query engine for the `US-States-Wiki` index
llama_cloud_query_engine = index.as_query_engine()

# %% [markdown]
# ## Create query tool around the engines

# %%
# Step 3: Create query tools around engines
from llama_index.core.tools import QueryEngineTool

# Create a tool for SQL queries
sql_tool = QueryEngineTool.from_defaults(
    query_engine=sql_query_engine,
    description=(
        "Useful for answering factual questions about US states like population, "
        "capital, land size, postal abbreviation, and other demographic statistics "
        "stored in a structured database."
    ),
    name="sql_tool"
)
# Create a tool for document-based queries
llama_cloud_tool = QueryEngineTool.from_defaults(
    query_engine=llama_cloud_query_engine,
    description=(
        f"Useful for answering questions about US states' history, attractions, culture, "
        f"geography, and other information that requires searching through documents. "
        f"This tool contains Wikipedia information about all US states."
    ),
    name="llama_cloud_tool"
)

# %% [markdown]
# ## Creating a ReAct Agentic workflow

# %%
# define tools
tools = [sql_tool, llama_cloud_tool]
# Create the agent with tools
from llama_index.core.agent import ReActAgent
agent = ReActAgent.from_tools(
    tools,
    llm=llm,
    verbose=True,
    system_prompt=(
        "You are an expert US States information system. "
        "You have access to two sources of information:\n\n"
        "1. A SQLite database with factual demographic data about US states in the 'states' table "
        "containing fields: object_id, name, flag_url, link, postal_abbreviation, capital, largest_city, "
        "established, population, total_area_square_miles, total_area_square_kilometers, land_area_square_miles, "
        "land_area_square_kilometers, water_area_square_miles, "
        "water_area_square_kilometers, number_representatives, created_at, updated_at\n\n"
        "2. Document retrieval for detailed information about history, attractions, and more\n\n"
        "Choose the appropriate tool based on the user's question. "
        "For the SQL tool, formulate clear SQL queries that match the database schema. "
        "Use the SQL tool for factual queries about population, area, capitals, etc. "
        "Use the document tool for questions about history, attractions, culture, and detailed information. "
        "If needed, you can use both tools and combine the information."
    )
)

# Step 5: Function to handle user queries
def answer_state_question(query):
    """
    Answer questions about US states using the appropriate tools.
    Args:
        query (str): User's natural language query
    Returns:
        str: Response to the user's query
    """
    try:
        # Use the agent to answer the query
        response = agent.query(query)
        #return str(response) 
        return response
    except Exception as e:
        return f"Sorry, I couldn't process your query. Error: {str(e)}"

# %% [markdown]
# ### Testing the ReActAgent

# %%
# Population question (should use SQL)
query = ("What is the population of California?")
print(f"\nQuestion: {query}")
print(f"Answer: {answer_state_question(query)}")
# Out:
# Question: What is the population of California?
# > Running step 1a22de77-350d-409f-9ff4-612c53bbd6ee. Step input: What is the population of California?
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question about the population of California. The `sql_tool` is suitable for retrieving specific demographic statistics like population for a US state.
# Action: sql_tool
# Action Input: {'input': 'What is the population of California?'}
# > Table Info: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Table desc str: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Predicted SQL query: SELECT population FROM states WHERE name = 'California'
# Observation: The population of California is 39,536,653.
# > Running step 5dc65459-5d62-49ef-85a7-a7a24a525eeb. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The population of California is 39,536,653.
# Answer: The population of California is 39,536,653.

# %%
# Semantic question (should use LlamaCloud tool)
query = ("What are popular tourist attractions in Hawaii?")
print(f"\nQuestion: {query}")
print(f"Answer: {answer_state_question(query)}")
# Out:
# Question: What are popular tourist attractions in Hawaii?
# > Running step fe448001-8e20-4566-926f-2560655bc455. Step input: What are popular tourist attractions in Hawaii?
# Thought: The current language of the user is: English. I need to find information about popular tourist attractions in Hawaii. The `llama_cloud_tool` is suitable for this as it can search through documents containing information about state attractions.
# Action: llama_cloud_tool
# Action Input: {'input': 'What are popular tourist attractions in Hawaii?'}
# Observation: Based on the provided information, Hawaii offers various attractions and events for visitors:
#
# *   **National Parks and Monuments:** These include Haleakalā National Park on Maui, featuring a dormant volcano, and Hawaii Volcanoes National Park on Hawaiʻi Island, which includes the active Kīlauea volcano. Other sites under the National Park Service are Kalaupapa National Historical Park on Molokaʻi, Kaloko-Honokōhau National Historical Park, Puʻuhonua o Hōnaunau National Historical Park, and Ala Kahakai National Historic Trail on Hawaiʻi Island, as well as the USS Arizona Memorial on Oʻahu. The Papahānaumokuākea Marine National Monument covers a vast area of reefs and atolls.
# *   **State Parks and Historical Sites:** Numerous state parks, recreation areas, and historical parks exist across the islands, such as Ahukini State Recreation Pier and Russian Fort Elizabeth State Historical Park on Kauaʻi, Polipoli Spring State Recreation Area on Maui, Pala'au State Park on Moloka'i, and Ulu Pō Heiau State Monument on Oʻahu. Nā Pali Coast State Park on Kauaʻi is also mentioned.
# *   **Natural Features:** Notable natural sites include Punaluʻu Beach on the Big Island, the North Shore of Oahu known for surfing, and the tall mountain Mauna Kea.
# *   **Cultural Events:** Hawaii hosts events like the Merrie Monarch Festival, an international Hula competition, and the Hawaii International Film Festival. Honolulu also hosts the Rainbow Film Festival.
# *   **Sporting Events:** Major sporting events held in Hawaii include the Sony Open, Tournament of Champions, and Lotte Championship golf tournaments; the Honolulu Marathon; the Ironman World Championship and Ultraman triathlons; and surfing competitions like the Triple Crown of Surfing and The Eddie. College sports events like the Maui Invitational Tournament, Diamond Head Classic, and Hawaii Bowl also take place.
# > Running step c11c0180-e932-43a5-8800-1736bbda3cf6. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: Hawaii offers a wide range of popular tourist attractions, including:
#
# *   **National Parks and Monuments:** Such as Haleakalā National Park on Maui (known for its dormant volcano), Hawaii Volcanoes National Park on Hawaiʻi Island (home to the active Kīlauea volcano), and the USS Arizona Memorial on Oʻahu.
# *   **State Parks and Historical Sites:** Including Nā Pali Coast State Park on Kauaʻi and numerous others across the islands offering scenic beauty and historical significance.
# *   **Natural Wonders:** Famous spots like Punaluʻu Beach (known for black sand) on the Big Island, the world-renowned surfing destination of Oahu's North Shore, and the towering Mauna Kea volcano.
# *   **Cultural Experiences:** Events like the Merrie Monarch Festival (a major Hula competition) and the Hawaii International Film Festival.
# *   **Major Sporting Events:** Including prestigious golf tournaments, the Honolulu Marathon, Ironman World Championship triathlon, and famous surfing competitions like the Triple Crown of Surfing.
# Answer: Hawaii offers a wide range of popular tourist attractions, including:
#
# *   **National Parks and Monuments:** Such as Haleakalā National Park on Maui (known for its dormant volcano), Hawaii Volcanoes National Park on Hawaiʻi Island (home to the active Kīlauea volcano), and the USS Arizona Memorial on Oʻahu.
# *   **State Parks and Historical Sites:** Including Nā Pali Coast State Park on Kauaʻi and numerous others across the islands offering scenic beauty and historical significance.
# *   **Natural Wonders:** Famous spots like Punaluʻu Beach (known for black sand) on the Big Island, the world-renowned surfing destination of Oahu's North Shore, and the towering Mauna Kea volcano.
# *   **Cultural Experiences:** Events like the Merrie Monarch Festival (a major Hula competition) and the Hawaii International Film Festival.
# *   **Major Sporting Events:** Including prestigious golf tournaments, the Honolulu Marathon, Ironman World Championship triathlon, and famous surfing competitions like the Triple Crown of Surfing.

# %%
# Contextual question (should use both SQL and LlamaCloud tools)
query = ("Tell me about the availability of water in Arizona. What is the water area in Arizona")
print(f"\nQuestion: {query}")
print(f"Answer: {answer_state_question(query)}")
# Out:
# Question: Tell me about the availability of water in Arizona. What is the water area in Arizona
# > Running step 8ecb4540-9076-4d8b-8dc9-9de98c45f813. Step input: Tell me about the availability of water in Arizona. What is the water area in Arizona
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.
# Thought: The user is asking two questions about Arizona: 1) general information about water availability, and 2) the specific water area statistic. The first question requires descriptive information likely found in documents, so I'll use the `llama_cloud_tool`. The second question asks for a specific statistic (water area), which is likely in the structured database, so I'll use the `sql_tool` for that. I'll start with the `llama_cloud_tool` for the general information. The user's language is English.
# Action: llama_cloud_tool
# Action Input: {'input': 'Describe the availability of water in Arizona, including sources and challenges.'}
# Observation: Arizona experiences significant stress on its water supply due to continued population growth. The state has a primarily dry climate, especially in the lower elevations which are characterized as desert. Average annual rainfall is 12.7 inches (323 mm), occurring mainly during two rainy seasons: winter, from Pacific cold fronts, and a summer monsoon season. While the summer monsoon can bring torrential downpours and flash floods, the overall climate, including the higher-altitude northern plateau, remains semiarid to arid. The Colorado River is a major geographical feature in the state.
# > Running step 1fa0292f-6b20-4a87-8562-4699e1f26022. Step input: None
# Thought: The user asked about water availability in Arizona and its water area. I used the `llama_cloud_tool` to get information about water availability, which highlighted Arizona's dry climate, reliance on rainfall and the Colorado River, and stress from population growth. Now I need to find the specific water area statistic for Arizona. The `sql_tool` is suitable for retrieving this kind of factual data.
# Action: sql_tool
# Action Input: {'input': 'What is the water area of Arizona?'}
# > Table Info: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Table desc str: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Predicted SQL query: SELECT water_area_square_miles FROM states WHERE name = "Arizona"
# Observation: Arizona has a water area of 396 square miles.
# > Running step e8ffe872-e332-416d-ade0-2be5b29ebd73. Step input: None
# Thought: I have gathered information from both tools. The `llama_cloud_tool` provided context on water availability in Arizona, mentioning its dry climate, rainfall patterns, the Colorado River, and population growth challenges. The `sql_tool` provided the specific water area. I can now combine this information to answer the user's questions.
# Answer: Arizona has a primarily dry, arid to semiarid climate, with an average annual rainfall of about 12.7 inches. Water availability is a significant concern due to this climate and continued population growth, which puts stress on the water supply. Key water sources include rainfall, particularly during the winter and summer monsoon seasons, and the Colorado River.
#
# Regarding its water area, Arizona has 396 square miles of water surface area.
# Answer: Arizona has a primarily dry, arid to semiarid climate, with an average annual rainfall of about 12.7 inches. Water availability is a significant concern due to this climate and continued population growth, which puts stress on the water supply. Key water sources include rainfall, particularly during the winter and summer monsoon seasons, and the Colorado River.
#
# Regarding its water area, Arizona has 396 square miles of water surface area.

# %% [markdown]
# ## Putting it all together

# %%
# Step 1: Set up the SQL Query Engine
import sqlalchemy as sa
from sqlalchemy.orm import sessionmaker
from dotenv import load_dotenv
import os
import asyncio

from llama_index.core.query_engine import NLSQLTableQueryEngine
from llama_index.core import SQLDatabase, Settings
from llama_index.llms.google_genai import GoogleGenAI

# Load environment variables
load_dotenv()

# Initialize LLM
llm = GoogleGenAI(
    model="models/gemini-2.5-pro-exp-03-25",
    google_api_key=os.getenv("GOOGLE_API_KEY"),
    temperature=0.3
)
Settings.llm = llm

# Connect to the database
engine = sa.create_engine('sqlite:///states.db', future=True)
Session = sessionmaker(bind=engine)
session = Session()

# Create the SQL database wrapper
sql_database = SQLDatabase(engine, include_tables=["states"])

# Create the natural language to SQL query engine
sql_query_engine = NLSQLTableQueryEngine(
    sql_database=sql_database,
    embed_model=llm,
    llm=llm,
    tables=["states"]
)

# Step 2: Initialize the LlamaCloud index for document retrieval
from llama_index.indices.managed.llama_cloud import LlamaCloudIndex

# Initialize the LlamaCloud index
index = LlamaCloudIndex(
    name="US-States-Wiki",
    project_name="sql_rag",
    organization_id=os.getenv("LLAMA_CLOUD_ORG_ID"),
    api_key=os.getenv("LLAMA_CLOUD_API_KEY")
)

# Create a query engine for the `US-States-Wiki` index
llama_cloud_query_engine = index.as_query_engine()

# Step 3: Create query tools around engines
from llama_index.core.tools import QueryEngineTool

# Create a tool for SQL queries
sql_tool = QueryEngineTool.from_defaults(
    query_engine=sql_query_engine,
    description=(
        "Useful for answering factual questions about US states like population, "
        "capital, land size, postal abbreviation, and other demographic statistics "
        "stored in a structured database."
    ),
    name="sql_tool"
)
# Create a tool for document-based queries
llama_cloud_tool = QueryEngineTool.from_defaults(
    query_engine=llama_cloud_query_engine,
    description=(
        f"Useful for answering questions about US states' history, attractions, culture, "
        f"geography, and other information that requires searching through documents. "
        f"This tool contains Wikipedia information about all US states."
    ),
    name="llama_cloud_tool"
)

# Step 4: Build the Agent with the tools
from llama_index.core.agent import ReActAgent

# Create a list of tools
tools = [sql_tool, llama_cloud_tool]

# Create the agent with tools
agent = ReActAgent.from_tools(
    tools,
    llm=llm,
    verbose=True,
    system_prompt=(
        "You are an expert US States information system. "
        "You have access to two sources of information:\n\n"
        "1. A SQLite database with factual demographic data about US states in the 'states' table "
        "containing fields: object_id, name, flag_url, link, postal_abbreviation, capital, largest_city, "
        "established, population, total_area_square_miles, total_area_square_kilometers, land_area_square_miles, "
        "land_area_square_kilometers, water_area_square_miles, "
        "water_area_square_kilometers, number_representatives, created_at, updated_at\n\n"
        "2. Document retrieval for detailed information about history, attractions, and more\n\n"
        "Choose the appropriate tool based on the user's question. "
        "For the SQL tool, formulate clear SQL queries that match the database schema. "
        "Use the SQL tool for factual queries about population, area, capitals, etc. "
        "Use the document tool for questions about history, attractions, culture, and detailed information. "
        "If needed, you can use both tools and combine the information."
    )
)

# Step 5: Function to handle user queries
def answer_state_question(query):
    """
    Answer questions about US states using the appropriate tools.
    
    Args:
        query (str): User's natural language query
        
    Returns:
        str: Response to the user's query
    """
    try:
        # Use the agent to answer the query
        response = agent.query(query)
        #return str(response) 
        return response
    except Exception as e:
        return f"Sorry, I couldn't process your query. Error: {str(e)}"

# Example usage
if __name__ == "__main__":
    # Test queries
    queries = [
        "What is the population of California?",
        "What are popular tourist attractions in Hawaii?",
        "Which state has the largest land area?",
        "Tell me about the history of New York."
    ]
    
    for query in queries:
        print(f"\nQuestion: {query}")
        print(f"Answer: {answer_state_question(query)}")
        print("-" * 80)
# Out:
# Question: What is the population of California?
# > Running step 8a6e3608-0ae4-4317-9822-ba2a4a261c56. Step input: What is the population of California?
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question. The user is asking for the population of California. This is a factual question about a US state's demographic statistics, which the `sql_tool` can answer.
# Action: sql_tool
# Action Input: {'input': 'What is the population of California?'}
# Observation: The population of California is 39,536,653.
# > Running step a98a81be-40c0-4c05-97a9-c8b568801e11. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The population of California is 39,536,653.
# Answer: The population of California is 39,536,653.
# --------------------------------------------------------------------------------
#
# Question: What are popular tourist attractions in Hawaii?
# > Running step 8b8104f4-7dd5-49ea-b269-8aaf202e661b. Step input: What are popular tourist attractions in Hawaii?
# Thought: The current language of the user is: English. I need to use a tool to find information about popular tourist attractions in Hawaii. The `llama_cloud_tool` is suitable for this as it contains information about state attractions from Wikipedia.
# Action: llama_cloud_tool
# Action Input: {'input': 'What are popular tourist attractions in Hawaii?'}
# Observation: Hawaii offers a variety of attractions for visitors. There are numerous state parks, recreation areas, and historical parks across the islands of Hawaiʻi, Kauaʻi, Maui, Molokaʻi, and Oʻahu. Specific examples include the Ahukini State Recreation Pier and Russian Fort Elizabeth State Historical Park on Kauaʻi, Polipoli Spring State Recreation Area on Maui, Pala'au State Park on Molokaʻi, Ulu Pō Heiau State Monument on Oʻahu, and Nā Pali Coast State Park on Kauaʻi.
#
# Areas protected by the National Park Service are also significant attractions. These include:
# *   Haleakalā National Park on Maui, featuring the dormant volcano Haleakalā.
# *   Hawaii Volcanoes National Park on Hawaiʻi Island, which encompasses the active volcano Kīlauea.
# *   Kalaupapa National Historical Park on Molokaʻi.
# *   Kaloko-Honokōhau National Historical Park on Hawaiʻi Island.
# *   Puʻuhonua o Hōnaunau National Historical Park on Hawaiʻi Island.
# *   Ala Kahakai National Historic Trail on Hawaiʻi Island.
# *   The USS Arizona Memorial at Pearl Harbor on Oʻahu.
#
# Additionally, Punaluʻu Beach on the Big Island and the North Shore of Oahu, known as a major site for surfing, are notable locations. The Papahānaumokuākea Marine National Monument protects a vast area of reefs and atolls in the Northwestern Hawaiian Islands.
# > Running step 0de9d4c2-30f8-40df-ace5-2281c1595741. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: Hawaii has many popular tourist attractions across its islands. Some key attractions include:
#
# *   **National Parks:** Haleakalā National Park on Maui (known for its dormant volcano) and Hawaii Volcanoes National Park on the Big Island (home to the active Kīlauea volcano).
# *   **Historical Sites:** The USS Arizona Memorial at Pearl Harbor on Oʻahu, Kalaupapa National Historical Park on Molokaʻi, Puʻuhonua o Hōnaunau National Historical Park, and Kaloko-Honokōhau National Historical Park on the Big Island.
# *   **Natural Wonders & Beaches:** The Nā Pali Coast State Park on Kauaʻi, Punaluʻu Beach (known for black sand) on the Big Island, and the famous North Shore of Oʻahu, renowned for surfing.
# *   **State Parks & Recreation Areas:** Numerous parks across all islands offer diverse experiences, such as Polipoli Spring State Recreation Area on Maui and Pala'au State Park on Molokaʻi.
# *   **Marine Monument:** The Papahānaumokuākea Marine National Monument protects a large area in the Northwestern Hawaiian Islands.
# Answer: Hawaii has many popular tourist attractions across its islands. Some key attractions include:
#
# *   **National Parks:** Haleakalā National Park on Maui (known for its dormant volcano) and Hawaii Volcanoes National Park on the Big Island (home to the active Kīlauea volcano).
# *   **Historical Sites:** The USS Arizona Memorial at Pearl Harbor on Oʻahu, Kalaupapa National Historical Park on Molokaʻi, Puʻuhonua o Hōnaunau National Historical Park, and Kaloko-Honokōhau National Historical Park on the Big Island.
# *   **Natural Wonders & Beaches:** The Nā Pali Coast State Park on Kauaʻi, Punaluʻu Beach (known for black sand) on the Big Island, and the famous North Shore of Oʻahu, renowned for surfing.
# *   **State Parks & Recreation Areas:** Numerous parks across all islands offer diverse experiences, such as Polipoli Spring State Recreation Area on Maui and Pala'au State Park on Molokaʻi.
# *   **Marine Monument:** The Papahānaumokuākea Marine National Monument protects a large area in the Northwestern Hawaiian Islands.
# --------------------------------------------------------------------------------
#
# Question: Which state has the largest land area?
# > Running step 04af5f72-54e6-45a4-b815-fe3ff8f04b84. Step input: Which state has the largest land area?
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question about which US state has the largest land area. This is a factual question about state statistics, so the `sql_tool` is appropriate.
# Action: sql_tool
# Action Input: {'input': 'Which state has the largest land area?'}
# Observation: Alaska has the largest land area with 570,641 square miles.
# > Running step 7e467e55-64d0-4b15-84bf-ed906122d380. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: Alaska has the largest land area with 570,641 square miles.
# Answer: Alaska has the largest land area with 570,641 square miles.
# --------------------------------------------------------------------------------
#
# Question: Tell me about the history of New York.
# > Running step 6812854e-a72e-4b55-b862-28fdce71b8d5. Step input: Tell me about the history of New York.
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question about the history of New York. The `llama_cloud_tool` is appropriate for retrieving historical information from documents.
# Action: llama_cloud_tool
# Action Input: {'input': 'History of New York'}
# Observation: Prior to European arrival, the region was primarily inhabited by Iroquoian and Algonquian tribes. The Iroquois Confederacy, currently comprising the Seneca, Cayuga, Onondaga, Oneida, Tuscarora, and Mohawk nations, was a significant presence. The Lenape people also resided in the area.
#
# European involvement began with Giovanni da Verrazzano's exploration in 1524 for the French crown, charting the Atlantic coast and entering New York Bay. In 1540, French traders briefly established a chateau on Castle Island near present-day Albany, but it was abandoned due to flooding.
#
# Henry Hudson's 1609 voyage for the Dutch East India Company, seeking a passage to Asia, led him into Upper New York Bay. This spurred Dutch interest in fur trading. In the 17th century, the Dutch established trading posts in the colony of New Netherland, including Fort Nassau (1614, near Albany), Fort Orange (1624, south of Albany, replacing Fort Nassau and evolving into Beverwijck and then Albany), Fort Amsterdam (1625, becoming New Amsterdam, now New York City), and Esopus (1653, now Kingston). The patroonship of Rensselaerswyck (1630), surrounding Albany, contributed to the colony's early success.
#
# The English captured the colony during the Second Anglo-Dutch War, governing it as the Province of New York. Although the Dutch briefly recaptured New York City in 1673 during the Third Anglo-Dutch War, renaming it New Orange, it was returned to English control under the Treaty of Westminster in 1674.
#
# During the 1760s, the Sons of Liberty formed in New York City, largely opposing the 1765 Stamp Act. The Stamp Act Congress met in the city that same year, issuing the Declaration of Rights and Grievances. Despite this, many residents remained Loyalists due to strong ties with Britain.
#
# In the American Revolution, about a third of the battles occurred in New York. The capture of Fort Ticonderoga in 1775 provided crucial supplies. New York initially abstained from the independence vote but endorsed the Declaration of Independence on July 9, 1776. A state constitution, drafted primarily by John Jay, was adopted on April 20, 1777, in Kingston, without popular ratification. George Clinton became the first governor on July 30, 1777.
#
# The Battle of Long Island (or Battle of Brooklyn) in August 1776 was the war's largest battle; the British victory led to their occupation of New York City, which became their North American base for the war's duration. The Continental Army captured a major British force at the Battle of Saratoga in 1777, influencing France's decision to ally with the revolutionaries.
#
# Four Iroquois nations sided with the British, while the Oneida and Tuscarora allied with the Americans. The Sullivan Expedition of 1779 destroyed numerous Iroquois villages in retaliation for frontier attacks. Post-war, the British ceded most Indigenous lands to the U.S., and allied Iroquois were forced out, resettling in Canada. New York sold large tracts of former Iroquois territory, spurring development in Upstate New York. British authority ended with the troop departure from New York City in 1783, an event later known as Evacuation Day.
#
# New York City served as the national capital under the Articles of Confederation. New Yorker Alexander Hamilton was a key advocate for the U.S. Constitution, contributing to The Federalist Papers published in city newspapers. New York ratified the Constitution on July 26, 1788, becoming the 11th state. The city remained the national capital until 1790, hosting George Washington's inauguration, the first Supreme Court session, and the drafting of the Bill of Rights.
#
# In the 19th century, transportation challenges in Western New York were addressed by the Erie Canal, promoted by Governor DeWitt Clinton, which connected New York City to the Great Lakes via the Hudson River and the canal itself.
# > Running step e0e0e42a-4f09-49d7-baa9-7f5487694e39. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: Here's a summary of the history of New York based on the information retrieved:
#
# **Indigenous Peoples and Early Exploration:**
# Before Europeans arrived, the area now known as New York was inhabited by various Indigenous groups, notably the Iroquoian (including the powerful Iroquois Confederacy) and Algonquian tribes like the Lenape. European exploration began with Giovanni da Verrazzano in 1524, sailing for France, followed by Henry Hudson in 1609, sailing for the Dutch East India Company. Hudson's voyage up the river that now bears his name spurred Dutch interest in the region, primarily for fur trading.
#
# **Dutch Colonization (New Netherland):**
# In the 17th century, the Dutch established the colony of New Netherland. Key settlements included Fort Nassau (near Albany, 1614), Fort Orange (later Albany, 1624), Fort Amsterdam (which became New Amsterdam and eventually New York City, 1625), and Esopus (now Kingston, 1653). The large land grant known as Rensselaerswyck (around Albany, 1630) was also significant.
#
# **English Control (Province of New York):**
# The English captured New Netherland during the Second Anglo-Dutch War (mid-1660s) and renamed it the Province of New York. Though the Dutch briefly recaptured New York City in 1673 (renaming it New Orange), it was permanently returned to English control by the Treaty of Westminster in 1674.
#
# **The American Revolution:**
# New York played a crucial role in the lead-up to and during the American Revolution. The Sons of Liberty were active in New York City opposing British policies like the Stamp Act (1765), and the city hosted the Stamp Act Congress. During the war, about a third of the battles were fought on New York soil. Key events included the capture of Fort Ticonderoga (1775), the Battle of Long Island (1776, a major British victory leading to their occupation of NYC), and the pivotal American victory at the Battle of Saratoga (1777), which helped secure French support. New York adopted its first state constitution in 1777 and George Clinton became the first governor. The Iroquois Confederacy was divided, with most nations siding with the British, leading to conflict and their eventual displacement after the war.
#
# **Early Statehood and National Role:**
# Following the Revolution, New York City served as the national capital under the Articles of Confederation and briefly under the new Constitution. New York ratified the U.S. Constitution in 1788, becoming the 11th state. Alexander Hamilton, a New Yorker, was instrumental in advocating for the Constitution through *The Federalist Papers*. The city hosted George Washington's inauguration, the first Supreme Court session, and the drafting of the Bill of Rights before the capital moved in 1790.
#
# **19th Century Development:**
# A major development in the early 19th century was the construction of the Erie Canal, championed by Governor DeWitt Clinton. Completed in 1825, it connected the Atlantic Ocean (via New York City and the Hudson River) to the Great Lakes, significantly boosting trade and settlement in Upstate New York and the Midwest.
# Answer: Here's a summary of the history of New York based on the information retrieved:
#
# **Indigenous Peoples and Early Exploration:**
# Before Europeans arrived, the area now known as New York was inhabited by various Indigenous groups, notably the Iroquoian (including the powerful Iroquois Confederacy) and Algonquian tribes like the Lenape. European exploration began with Giovanni da Verrazzano in 1524, sailing for France, followed by Henry Hudson in 1609, sailing for the Dutch East India Company. Hudson's voyage up the river that now bears his name spurred Dutch interest in the region, primarily for fur trading.
#
# **Dutch Colonization (New Netherland):**
# In the 17th century, the Dutch established the colony of New Netherland. Key settlements included Fort Nassau (near Albany, 1614), Fort Orange (later Albany, 1624), Fort Amsterdam (which became New Amsterdam and eventually New York City, 1625), and Esopus (now Kingston, 1653). The large land grant known as Rensselaerswyck (around Albany, 1630) was also significant.
#
# **English Control (Province of New York):**
# The English captured New Netherland during the Second Anglo-Dutch War (mid-1660s) and renamed it the Province of New York. Though the Dutch briefly recaptured New York City in 1673 (renaming it New Orange), it was permanently returned to English control by the Treaty of Westminster in 1674.
#
# **The American Revolution:**
# New York played a crucial role in the lead-up to and during the American Revolution. The Sons of Liberty were active in New York City opposing British policies like the Stamp Act (1765), and the city hosted the Stamp Act Congress. During the war, about a third of the battles were fought on New York soil. Key events included the capture of Fort Ticonderoga (1775), the Battle of Long Island (1776, a major British victory leading to their occupation of NYC), and the pivotal American victory at the Battle of Saratoga (1777), which helped secure French support. New York adopted its first state constitution in 1777 and George Clinton became the first governor. The Iroquois Confederacy was divided, with most nations siding with the British, leading to conflict and their eventual displacement after the war.
#
# **Early Statehood and National Role:**
# Following the Revolution, New York City served as the national capital under the Articles of Confederation and briefly under the new Constitution. New York ratified the U.S. Constitution in 1788, becoming the 11th state. Alexander Hamilton, a New Yorker, was instrumental in advocating for the Constitution through *The Federalist Papers*. The city hosted George Washington's inauguration, the first Supreme Court session, and the drafting of the Bill of Rights before the capital moved in 1790.
#
# **19th Century Development:**
# A major development in the early 19th century was the construction of the Erie Canal, championed by Governor DeWitt Clinton. Completed in 1825, it connected the Atlantic Ocean (via New York City and the Hudson River) to the Great Lakes, significantly boosting trade and settlement in Upstate New York and the Midwest.
# --------------------------------------------------------------------------------

# %%
import sqlalchemy as sa
from sqlalchemy.orm import sessionmaker
from sqlalchemy import inspect
from dotenv import load_dotenv
import os
from IPython.display import display, Markdown
import asyncio

from llama_index.core.query_engine import NLSQLTableQueryEngine
from llama_index.core import SQLDatabase, Settings
from llama_index.llms.google_genai import GoogleGenAI

# Load environment variables
load_dotenv()

# Initialize LLM
llm = GoogleGenAI(
    model="models/gemini-2.5-pro-exp-03-25",
    google_api_key=os.getenv("GOOGLE_API_KEY"),
    temperature=0.3
)
Settings.llm = llm

# Connect to the database
engine = sa.create_engine('sqlite:///states.db', future=True)
Session = sessionmaker(bind=engine)
session = Session()

# Get detailed table schema information
inspector = inspect(engine)
table_columns = {}
for table_name in inspector.get_table_names():
    columns = inspector.get_columns(table_name)
    table_columns[table_name] = [column['name'] for column in columns]

# Display available tables and columns for debugging
print("Available tables and columns:")
for table, columns in table_columns.items():
    print(f"Table: {table}")
    print(f"Columns: {', '.join(columns)}")
    print("-" * 80)

# Create the SQL database wrapper with explicit table info
sql_database = SQLDatabase(engine, include_tables=["states"])

# Generate sample data description to help the LLM understand the data structure
# This creates better context for the NLSQLTableQueryEngine
table_schema_str = """
Database Schema:
- states table:
  - object_id: Object ID like 
  - name: State name (e.g., "California", "Texas")
  - flag_url: link to states flag png image
  - link: url link to states page
  - postal_abbreviation: Two-letter state code (e.g., "CA", "TX")
  - capital: Capital city name
  - largest_city: name of largest city
  - established: date when state was established
  - population: state's population
  - total_area_square_miles= state total area in square miles
  - total_area_square_kilometers: total area in square kilometers
  - land_area_square_miles: land area in square miles
  - land_area_square_kilometers: land area in square kilometers
  - water_area_square_miles: water area in square miles
  - water_area_square_kilometers: water area in square kilometers
  - number_representatives: number of representatives
  - created_at: date of database creation
  - updated_at: date of database update
"""

# Create the natural language to SQL query engine with more context
sql_query_engine = NLSQLTableQueryEngine(
    sql_database=sql_database,
    tables=["states"],
    sample_rows_in_table_info=2,  # Include sample rows to provide better context
    llm=llm,
    embed_model=llm,
    synthesize_response=True,
    table_schema_str=table_schema_str,
    verbose=True  # This enables debug output to see the generated SQL
)

# Step 2: Initialize the LlamaCloud index for document retrieval
from llama_index.indices.managed.llama_cloud import LlamaCloudIndex

# Initialize the LlamaCloud index
index = LlamaCloudIndex(
    name="US-States-Wiki",
    project_name="sql_rag",
    organization_id=os.getenv("LLAMA_CLOUD_ORG_ID"),
    api_key=os.getenv("LLAMA_CLOUD_API_KEY")
)

# Create a query engine for the `US-States-Wiki` index
llama_cloud_query_engine = index.as_query_engine()

# Step 3: Create query tools around engines
from llama_index.core.tools import QueryEngineTool

# Create a tool for SQL queries with more specific description
sql_tool = QueryEngineTool.from_defaults(
    query_engine=sql_query_engine,
    description=(
        "Useful for answering factual questions about US states like population, "
        "capital, land size, postal abbreviation, and other demographic statistics "
        "stored in a structured database. The states table contains fields: "
        "name, abbreviation, capital, population, area_sq_miles, region, "
        "admitted_to_union, and median_household_income."
    ),
    name="sql_tool"
)

# Create a tool for document-based queries
llama_cloud_tool = QueryEngineTool.from_defaults(
    query_engine=llama_cloud_query_engine,
    description=(
        f"Useful for answering questions about US states' history, attractions, culture, "
        f"geography, and other information that requires searching through documents. "
        f"This tool contains Wikipedia information about all US states."
    ),
    name="llama_cloud_tool"
)

# Step 4: Build the Agent with the tools
from llama_index.core.agent import ReActAgent

# Create a list of tools
tools = [sql_tool, llama_cloud_tool]

# Create the agent with tools and improved system prompt
agent = ReActAgent.from_tools(
    tools,
    llm=llm,
    verbose=True,
    system_prompt=(
        "You are an expert US States information system. "
        "You have access to two sources of information:\n\n"
        "1. A SQLite database with factual demographic data about US states in the 'states' table "
        "containing fields: object_id, name, flag_url, link, postal_abbreviation, capital, largest_city, "
        "established, population, total_area_square_miles, total_area_square_kilometers, land_area_square_miles, "
        "land_area_square_kilometers, water_area_square_miles, "
        "water_area_square_kilometers, number_representatives, created_at, updated_at\n\n"
        "2. Document retrieval for detailed information about history, attractions, and more\n\n"
        "Choose the appropriate tool based on the user's question. "
        "For the SQL tool, formulate clear SQL queries that match the database schema. "
        "Use the SQL tool for factual queries about population, area, capitals, etc. "
        "Use the document tool for questions about history, attractions, culture, and detailed information. "
        "If needed, you can use both tools and combine the information."
    )
)

# Step 5: Function to handle user queries with better error handling
def answer_state_question(query):
    """
    Answer questions about US states using the appropriate tools.
    Args:
        query (str): User's natural language query 
    Returns:
        str: Response to the user's query
    """
    try:
        # Use the agent to answer the query
        response = agent.query(query)
        return response
    except Exception as e:
        print(f"Error details: {str(e)}")
        # Try a more direct approach if the agent fails
        try:
            # For simple factual queries, use the SQL tool directly
            if any(word in query.lower() for word in ['population', 'capital', 'area', 'largest', 'smallest']):
                print("Falling back to direct SQL query...")
                return sql_query_engine.query(query)
            else:
                # For other queries, use the document tool directly
                print("Falling back to direct document query...")
                return llama_cloud_query_engine.query(query)
        except Exception as fallback_error:
            return f"Sorry, I couldn't process your query. Error: {str(e)}\nFallback error: {str(fallback_error)}"

# Example usage
if __name__ == "__main__":
    # Test queries focusing on SQL capabilities
    queries = [
        "What is the population of California?",
        "Which state has the largest land area?",
        "List the top 5 most populous states",
        "What is the capital of Texas?",
        "Which states have a population greater than 10 million?",
    ]
    
    for query in queries:
        print(f"\nQuestion: {query}")
        print(f"Answer: {answer_state_question(query)}")
        print("-" * 80)
# Out:
# Available tables and columns:
# Table: states
# Columns: id, object_id, name, flag_url, link, postal_abbreviation, capital, largest_city, established, population, total_area_square_miles, total_area_square_kilometers, land_area_square_miles, land_area_square_kilometers, water_area_square_miles, water_area_square_kilometers, number_representatives, created_at, updated_at, capitals_object_id
# --------------------------------------------------------------------------------
#
# Question: What is the population of California?
# > Running step 3862da18-729e-41d5-a1a6-608feda321df. Step input: What is the population of California?
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question about the population of California. The `sql_tool` is suitable for retrieving specific demographic statistics like population for a US state.
# Action: sql_tool
# Action Input: {'input': 'What is the population of California?'}
# > Table Info: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Table desc str: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Predicted SQL query: SELECT population FROM states WHERE name = 'California'
# Observation: The population of California is 39,536,653.
# > Running step a881be77-2991-4742-97aa-45d43099c063. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The population of California is 39,536,653.
# Answer: The population of California is 39,536,653.
# --------------------------------------------------------------------------------
#
# Question: Which state has the largest land area?
# > Running step a073f6e5-2c8d-41a6-bcc6-cc05e4004a88. Step input: Which state has the largest land area?
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question. The question asks for the US state with the largest land area. This information is available in the `states` table via the `sql_tool`. I should query the table for the state name, order by the `area_sq_miles` column in descending order, and limit the result to 1.
# Action: sql_tool
# Action Input: {'input': 'SELECT name FROM states ORDER BY area_sq_miles DESC LIMIT 1'}
# > Table Info: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Table desc str: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Predicted SQL query: SELECT name FROM states ORDER BY total_area_square_miles DESC LIMIT 1
# Observation: Alaska
# > Running step 255440dc-988b-44e0-a397-a41afaa4189b. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: Alaska has the largest land area.
# Answer: Alaska has the largest land area.
# --------------------------------------------------------------------------------
#
# Question: List the top 5 most populous states
# > Running step 427a5d6a-abde-45f2-8dca-13ce0e989a4c. Step input: List the top 5 most populous states
# Thought: The current language of the user is: English. I need to use the sql_tool to find the top 5 most populous states.
# Action: sql_tool
# Action Input: {'input': 'SELECT name, population FROM states ORDER BY population DESC LIMIT 5;'}
# > Table Info: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Table desc str: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Predicted SQL query: SELECT name, population FROM states ORDER BY population DESC LIMIT 5;
# Observation: The 5 most populous states are:
# 1.  California (39,536,653)
# 2.  Texas (28,304,596)
# 3.  Florida (20,984,400)
# 4.  New York (19,849,399)
# 5.  Pennsylvania (12,805,537)
# > Running step 5fe2cfc8-d170-401d-bdbc-8a0bc9a142fd. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The top 5 most populous states in the US are:
# 1.  California (39,536,653)
# 2.  Texas (28,304,596)
# 3.  Florida (20,984,400)
# 4.  New York (19,849,399)
# 5.  Pennsylvania (12,805,537)
# Answer: The top 5 most populous states in the US are:
# 1.  California (39,536,653)
# 2.  Texas (28,304,596)
# 3.  Florida (20,984,400)
# 4.  New York (19,849,399)
# 5.  Pennsylvania (12,805,537)
# --------------------------------------------------------------------------------
#
# Question: What is the capital of Texas?
# > Running step a10265a5-5609-4920-bebf-ba9ce93440e6. Step input: What is the capital of Texas?
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question. The user is asking for the capital of Texas. This is a factual question about a US state and can be answered using the `sql_tool`.
# Action: sql_tool
# Action Input: {'input': 'What is the capital of Texas?'}
# > Table Info: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Table desc str: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Predicted SQL query: SELECT capital FROM states WHERE name = 'Texas'
# Observation: Austin
# > Running step 8f7592ef-66df-4af0-9c9e-00d1102cb307. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The capital of Texas is Austin.
# Answer: The capital of Texas is Austin.
# --------------------------------------------------------------------------------
#
# Question: Which states have a population greater than 10 million?
# > Running step 12d825b4-55f8-4c88-8539-d103585caad2. Step input: Which states have a population greater than 10 million?
# Thought: The current language of the user is: English. I need to use the `sql_tool` to query the database for states with a population greater than 10,000,000.
# Action: sql_tool
# Action Input: {'input': 'SELECT name FROM states WHERE population > 10000000'}
# > Table Info: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Table desc str: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Predicted SQL query: SELECT name FROM states WHERE population > 10000000
# Observation: The states with a population greater than 10,000,000 are California, Florida, Georgia, Illinois, New York, North Carolina, Ohio, Pennsylvania, and Texas.
# > Running step e70e3a64-4f83-4ae5-ad84-6402734180d1. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The states with a population greater than 10 million are California, Florida, Georgia, Illinois, New York, North Carolina, Ohio, Pennsylvania, and Texas.
# Answer: The states with a population greater than 10 million are California, Florida, Georgia, Illinois, New York, North Carolina, Ohio, Pennsylvania, and Texas.
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Final version

# %%
import sqlalchemy as sa
from sqlalchemy.orm import sessionmaker
from sqlalchemy import inspect
from dotenv import load_dotenv
import os

import asyncio

from llama_index.core.query_engine import NLSQLTableQueryEngine
from llama_index.core import SQLDatabase, Settings
from llama_index.llms.google_genai import GoogleGenAI

# Load environment variables
load_dotenv()

# 1. Initialize LLM
llm = GoogleGenAI(
    model="models/gemini-2.5-pro-exp-03-25",
    google_api_key=os.getenv("GOOGLE_API_KEY"),
    temperature=0.3
)
Settings.llm = llm

# 2. Connect to the database
engine = sa.create_engine('sqlite:///states.db', future=True)

# Create the SQL database wrapper with explicit table info
sql_database = SQLDatabase(engine, include_tables=["states"])

# Generate sample data description to help the LLM understand the data structure
# This creates better context for the NLSQLTableQueryEngine
table_schema_str = """
Database Schema:
- states table:
  - object_id: Object ID like 
  - name: State name (e.g., "California", "Texas")
  - flag_url: link to states flag png image
  - link: url link to states page
  - postal_abbreviation: Two-letter state code (e.g., "CA", "TX")
  - capital: Capital city name
  - largest_city: name of largest city
  - established: date when state was established
  - population: state's population
  - total_area_square_miles= state total area in square miles
  - total_area_square_kilometers: total area in square kilometers
  - land_area_square_miles: land area in square miles
  - land_area_square_kilometers: land area in square kilometers
  - water_area_square_miles: water area in square miles
  - water_area_square_kilometers: water area in square kilometers
  - number_representatives: number of representatives
  - created_at: date of database creation
  - updated_at: date of database update
"""

# Create the natural language to SQL query engine with more context
sql_query_engine = NLSQLTableQueryEngine(
    sql_database=sql_database,
    tables=["states"],
    sample_rows_in_table_info=1,  # Include sample rows to provide better context
    llm=llm,
    embed_model=llm,
    synthesize_response=True,
    markdown_response=True,
    table_schema_str=table_schema_str,
    verbose=True  # This enables debug output to see the generated SQL
)

# Step 2: Initialize the LlamaCloud index for document retrieval
from llama_index.indices.managed.llama_cloud import LlamaCloudIndex

# Initialize the LlamaCloud index
index = LlamaCloudIndex(
    name="US-States-Wiki",
    project_name="sql_rag",
    organization_id=os.getenv("LLAMA_CLOUD_ORG_ID"),
    api_key=os.getenv("LLAMA_CLOUD_API_KEY")
)

# Create a query engine for the `US-States-Wiki` index
llama_cloud_query_engine = index.as_query_engine()

# Step 3: Create query tools around engines
from llama_index.core.tools import QueryEngineTool

# Create a tool for SQL queries with more specific description
sql_tool = QueryEngineTool.from_defaults(
    query_engine=sql_query_engine,
    description=(
        "Useful for answering factual questions about US states like population, "
        "capital, land size, postal abbreviation, and other demographic statistics "
        "stored in a structured database. The states table contains fields: "
        "name, abbreviation, capital, population, area_sq_miles, region, "
        "admitted_to_union, and median_household_income."
    ),
    name="sql_tool"
)

# Create a tool for document-based queries
llama_cloud_tool = QueryEngineTool.from_defaults(
    query_engine=llama_cloud_query_engine,
    description=(
        f"Useful for answering questions about US states' history, attractions, culture, "
        f"geography, and other information that requires searching through documents. "
        f"This tool contains Wikipedia information about all US states."
    ),
    name="llama_cloud_tool"
)

# Step 4: Build the Agent with the tools
from llama_index.core.agent import ReActAgent

# Create a list of tools
tools = [sql_tool, llama_cloud_tool]

# Create the agent with tools and improved system prompt
agent = ReActAgent.from_tools(
    tools,
    llm=llm,
    verbose=True,
    system_prompt=(
        "You are an expert US States information system. "
        "You have access to two sources of information:\n\n"
        "1. A SQLite database with factual demographic data about US states in the 'states' table "
        "containing fields: object_id, name, flag_url, link, postal_abbreviation, capital, largest_city, "
        "established, population, total_area_square_miles, total_area_square_kilometers, land_area_square_miles, "
        "land_area_square_kilometers, water_area_square_miles, "
        "water_area_square_kilometers, number_representatives, created_at, updated_at\n\n"
        "2. Document retrieval for detailed information about history, attractions, and more\n\n"
        "Choose the appropriate tool based on the user's question. "
        "For the SQL tool, formulate clear SQL queries that match the database schema. "
        "Use the SQL tool for factual queries about population, area, capitals, etc. "
        "Use the document tool for questions about history, attractions, culture, and detailed information. "
        "If needed, you can use both tools and combine the information."
    )
)

# Step 5: Function to handle user queries
def answer_state_question(query):
    """
    Answer questions about US states using the appropriate tools.
    Args:
        query (str): User's natural language query 
    Returns:
        str: Response to the user's query
    """
    try:
        # Use the agent to answer the query
        response = agent.query(query)
        return response
    except Exception as e:
        print(f"Error details: {str(e)}")
        # Try a more direct approach if the agent fails
        try:
            # For simple factual queries, use the SQL tool directly
            if any(word in query.lower() for word in ['population', 'capital', 'area', 'largest', 'smallest']):
                print("Falling back to direct SQL query...")
                return sql_query_engine.query(query)
            else:
                # For other queries, use the document tool directly
                print("Falling back to direct document query...")
                return llama_cloud_query_engine.query(query)
        except Exception as fallback_error:
            return f"Sorry, I couldn't process your query. Error: {str(e)}\nFallback error: {str(fallback_error)}"

# Example usage
if __name__ == "__main__":
    # Test queries focusing on SQL capabilities
    queries = [
        "What is the population of California?",
        "Which state has the largest land area?",
        "List the top 5 most populous states",
        "What is the capital of Texas?",
        "Which states have a population greater than 10 million?",
    ]
    
    for query in queries:
        print(f"\nQuestion: {query}")
        print(f"Answer: {answer_state_question(query)}")
        print("-" * 80)
# Out:
# Question: What is the population of California?
# > Running step dfad9c12-e8a8-4dd8-b543-88cfe0b4b9a5. Step input: What is the population of California?
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question about the population of California. The `sql_tool` is suitable for retrieving specific demographic data like population from a structured database about US states.
# Action: sql_tool
# Action Input: {'input': 'What is the population of California?'}
# > Table Info: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Table desc str: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Predicted SQL query: SELECT population FROM states WHERE name = 'California'
# Observation: The population of California is 39,536,653.
# > Running step 84f569f2-e211-4d75-af03-249b007d8bd6. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The population of California is 39,536,653.
# Answer: The population of California is 39,536,653.
# --------------------------------------------------------------------------------
#
# Question: Which state has the largest land area?
# > Running step 1f4ddc1b-2a00-48a0-908f-a72997879cd3. Step input: Which state has the largest land area?
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question. The question asks for the US state with the largest land area. This information is available in the `states` table accessible via the `sql_tool`. I can query the table to find the state with the maximum `area_sq_miles`.
# Action: sql_tool
# Action Input: {'input': 'SELECT name, area_sq_miles FROM states ORDER BY area_sq_miles DESC LIMIT 1'}
# > Table Info: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Table desc str: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Predicted SQL query: SELECT name, total_area_square_miles FROM states ORDER BY total_area_square_miles DESC LIMIT 1
# Observation: Alaska is the largest state by area, with 665,384 square miles.
# > Running step 69a98f69-5595-4248-af5d-4cc525fb0ed6. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: Alaska has the largest land area, covering 665,384 square miles.
# Answer: Alaska has the largest land area, covering 665,384 square miles.
# --------------------------------------------------------------------------------
#
# Question: List the top 5 most populous states
# > Running step dac207e6-59b3-48c9-81d9-a4a0e912f31a. Step input: List the top 5 most populous states
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question. The user is asking for the top 5 most populous states. This information is available in the `states` table accessible via the `sql_tool`. I need to query the table, order by population in descending order, and limit the result to 5.
# Action: sql_tool
# Action Input: {'input': 'SELECT name FROM states ORDER BY population DESC LIMIT 5'}
# > Table Info: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Table desc str: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Predicted SQL query: SELECT name FROM states ORDER BY population DESC LIMIT 5
# Observation: The 5 most populous states are California, Texas, Florida, New York, and Pennsylvania.
# > Running step 78622cb4-7329-4eea-9415-59e00278f680. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The top 5 most populous states are California, Texas, Florida, New York, and Pennsylvania.
# Answer: The top 5 most populous states are California, Texas, Florida, New York, and Pennsylvania.
# --------------------------------------------------------------------------------
#
# Question: What is the capital of Texas?
# > Running step f0c40709-1b0e-450d-bd9f-a9a91b94b887. Step input: What is the capital of Texas?
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question. The question asks for the capital of Texas. This information is likely stored in the structured database accessible via the `sql_tool`. I will query the database for the capital of the state named 'Texas'.
# Action: sql_tool
# Action Input: {'input': "SELECT capital FROM states WHERE name = 'Texas'"}
# > Table Info: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Table desc str: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Predicted SQL query: SELECT capital FROM states WHERE name = 'Texas'
# Observation: Austin
# > Running step ae311c98-dd12-4dce-9d42-c4f222d9bdae. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The capital of Texas is Austin.
# Answer: The capital of Texas is Austin.
# --------------------------------------------------------------------------------
#
# Question: Which states have a population greater than 10 million?
# > Running step 5294f6bb-1f53-4a0b-8d15-3d983969e152. Step input: Which states have a population greater than 10 million?
# Thought: The current language of the user is: English. I need to use the `sql_tool` to query the database for states with a population greater than 10 million.
# Action: sql_tool
# Action Input: {'input': 'SELECT name FROM states WHERE population > 10000000'}
# > Table Info: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Table desc str: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Predicted SQL query: SELECT name FROM states WHERE population > 10000000
# Observation: The states with a population greater than 10,000,000 are California, Florida, Georgia, Illinois, New York, North Carolina, Ohio, Pennsylvania, and Texas.
# > Running step 448d1f99-fcf4-4446-89dd-6922cee6652e. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The states with a population greater than 10 million are California, Florida, Georgia, Illinois, New York, North Carolina, Ohio, Pennsylvania, and Texas.
# Answer: The states with a population greater than 10 million are California, Florida, Georgia, Illinois, New York, North Carolina, Ohio, Pennsylvania, and Texas.
# --------------------------------------------------------------------------------

# %%
import sqlalchemy as sa
from sqlalchemy import text
import pandas as pd

# Connect to the database
engine = sa.create_engine('sqlite:///states.db', future=True)

def execute_query(query_str, params=None):
    """Execute a SQL query and return the results"""
    try:
        with engine.connect() as conn:
            if params:
                result = conn.execute(text(query_str), params)
            else:
                result = conn.execute(text(query_str))
            
            # Convert results to DataFrame for nice display
            df = pd.DataFrame(result.fetchall())
            if not df.empty:
                df.columns = result.keys()
            return df
    except Exception as e:
        return f"Error: {str(e)}"

# First, let's see the table structure
def get_table_info():
    """Get the table structure and sample data"""
    schema_query = "PRAGMA table_info(states)"
    schema_df = execute_query(schema_query)
    print("Table Structure:")
    print(schema_df)
    print("\n")
    
    # Get sample data
    sample_query = "SELECT * FROM states LIMIT 5"
    sample_df = execute_query(sample_query)
    print("Sample Data:")
    print(sample_df)
    print("\n")
    
    # Count total rows
    count_query = "SELECT COUNT(*) as count FROM states"
    count_df = execute_query(count_query)
    print("Total States:")
    print(count_df)
    print("\n")

# Test different ways to query states by name
def test_name_queries():
    print("Testing different ways to query state names:")
    
    # Test 1: Double quotes
    print("\nTest 1: Double quotes")
    query1 = 'SELECT capital FROM states WHERE name = "Texas"'
    print(f"Query: {query1}")
    print(execute_query(query1))
    
    # Test 2: Single quotes
    print("\nTest 2: Single quotes")
    query2 = "SELECT capital FROM states WHERE name = 'Texas'"
    print(f"Query: {query2}")
    print(execute_query(query2))
    
    # Test 3: Parameter binding
    print("\nTest 3: Parameter binding")
    query3 = "SELECT capital FROM states WHERE name = :state_name"
    print(f"Query: {query3} with params: {{'state_name': 'Texas'}}")
    print(execute_query(query3, {"state_name": "Texas"}))
    
    # Test 4: LIKE operator
    print("\nTest 4: LIKE operator")
    query4 = "SELECT capital FROM states WHERE name LIKE '%Texas%'"
    print(f"Query: {query4}")
    print(execute_query(query4))
    
    # Test 5: Case insensitive comparison
    print("\nTest 5: Case insensitive comparison")
    query5 = "SELECT capital FROM states WHERE LOWER(name) = LOWER('Texas')"
    print(f"Query: {query5}")
    print(execute_query(query5))

# Test working queries
def test_working_queries():
    print("Testing working queries:")
    
    # Population query
    print("\nPopulation query:")
    query1 = "SELECT name, population FROM states WHERE population > 10000000 ORDER BY population DESC"
    print(f"Query: {query1}")
    print(execute_query(query1))
    
    # Top 5 populous states
    print("\nTop 5 populous states:")
    query2 = "SELECT name, population FROM states ORDER BY population DESC LIMIT 5"
    print(f"Query: {query2}")
    print(execute_query(query2))
    
    # Area query
    print("\nLargest states by area:")
    query3 = "SELECT name, area_sq_miles FROM states ORDER BY area_sq_miles DESC LIMIT 5"
    print(f"Query: {query3}")
    print(execute_query(query3))

# Check for exact state name formats
def check_state_names():
    print("Checking exact state name formats in the database:")
    query = "SELECT name FROM states"
    state_names = execute_query(query)
    print(state_names)
    print("\n")
    
    # Check for Texas specifically
    print("Looking for Texas with exact matching:")
    for name in state_names['name'].values:
        if 'texas' in name.lower():
            print(f"Found: '{name}'")

# Run the tests
if __name__ == "__main__":
    print("=== SQLite States Database Test ===\n")
    get_table_info()
    check_state_names()
    test_name_queries()
    test_working_queries()
    
    # Based on test results, recommend fixes
    print("\n=== RECOMMENDATIONS ===")
    print("If all tests with state names failed, use this query function in your agent:")
    print("""
def fixed_sql_query(query_str):
    \"\"\"Fix and execute SQL queries for states database\"\"\"
    # Replace double quotes with single quotes for string literals
    query_str = query_str.replace('\"', '\'')
    
    # When using state names or text fields, use parameter binding
    # Example:
    # Instead of: SELECT * FROM states WHERE name = 'Texas'
    # Use: SELECT * FROM states WHERE LOWER(name) = LOWER(:state_name)
    # And pass parameters: {"state_name": "Texas"}
    
    # For the agent integration, consider using text comparison functions
    # to handle case sensitivity and possible formatting issues
    return query_str
    """)
# Out:
# === SQLite States Database Test ===
#
# Table Structure:
#     cid                          name          type  notnull dflt_value  pk
# 0     0                            id       INTEGER        1       None   1
# 1     1                     object_id   VARCHAR(50)        0       None   0
# 2     2                          name   VARCHAR(50)        1       None   0
# 3     3                      flag_url  VARCHAR(255)        0       None   0
# 4     4                          link  VARCHAR(100)        0       None   0
# 5     5           postal_abbreviation    VARCHAR(2)        0       None   0
# 6     6                       capital   VARCHAR(50)        0       None   0
# 7     7                  largest_city   VARCHAR(50)        0       None   0
# 8     8                   established   VARCHAR(50)        0       None   0
# 9     9                    population       INTEGER        0       None   0
# 10   10       total_area_square_miles       INTEGER        0       None   0
# 11   11  total_area_square_kilometers       INTEGER        0       None   0
# 12   12        land_area_square_miles       INTEGER        0       None   0
# 13   13   land_area_square_kilometers       INTEGER        0       None   0
# 14   14       water_area_square_miles       INTEGER        0       None   0
# 15   15  water_area_square_kilometers       INTEGER        0       None   0
# 16   16        number_representatives       INTEGER        0       None   0
# 17   17                    created_at  VARCHAR(100)        0       None   0
# 18   18                    updated_at  VARCHAR(100)        0       None   0
# 19   19            capitals_object_id   VARCHAR(50)        0       None   0
#
#
# Sample Data:
#    id   object_id        name  \
# 0   1  B9IfALchYP     Alabama
# 1   2  zq8GVoD1n0      Alaska
# 2   3  9DhrhBxbKN     Arizona
# 3   4  UGNHGooffs    Arkansas
# 4   5  ta1PtZdnvM  California
#
#                                             flag_url              link  \
# 0  https://upload.wikimedia.org/wikipedia/commons...     /wiki/Alabama
# 1  https://upload.wikimedia.org/wikipedia/commons...      /wiki/Alaska
# 2  https://upload.wikimedia.org/wikipedia/commons...     /wiki/Arizona
# 3  https://upload.wikimedia.org/wikipedia/commons...    /wiki/Arkansas
# 4  https://upload.wikimedia.org/wikipedia/commons...  /wiki/California
#
#   postal_abbreviation      capital largest_city   established  population  \
# 0                  AL   Montgomery   Birmingham  Dec 14, 1819     4874747
# 1                  AK       Juneau    Anchorage   Jan 3, 1959      739795
# 2                  AZ      Phoenix      Phoenix  Feb 14, 1912     7016270
# 3                  AR  Little Rock  Little Rock  Jun 15, 1836     3004279
# 4                  CA   Sacramento  Los Angeles   Sep 9, 1850    39536653
#
#    total_area_square_miles  total_area_square_kilometers  \
# 0                    52420                        135767
# 1                   665384                       1723337
# 2                   113990                        295234
# 3                    53179                        137732
# 4                   163695                        423967
#
#    land_area_square_miles  land_area_square_kilometers  \
# 0                   50645                       131171
# 1                  570641                      1477953
# 2                  113594                       294207
# 3                   52035                       134771
# 4                  155779                       403466
#
#    water_area_square_miles  water_area_square_kilometers  \
# 0                     1775                          4597
# 1                    94743                        245384
# 2                      396                          1026
# 3                     1143                          2961
# 4                     7916                         20501
#
#    number_representatives                created_at                updated_at  \
# 0                       7  2019-12-06T19:36:50.117Z  2019-12-09T23:20:36.439Z
# 1                       1  2019-12-06T19:36:50.597Z  2019-12-09T23:20:25.520Z
# 2                       9  2019-12-06T19:36:50.877Z  2019-12-09T23:18:34.311Z
# 3                       4  2019-12-06T19:36:51.153Z  2019-12-09T23:16:24.718Z
# 4                      53  2019-12-06T19:36:51.430Z  2019-12-09T23:20:09.986Z
#
#   capitals_object_id
# 0         t0wuThlqBx
# 1         xknNfY6ZcD
# 2         5vGAgNr4C8
# 3         BaNFmSEwrN
# 4         MvNSUoM9Cq
#
#
# Total States:
#    count
# 0     50
#
#
# Checking exact state name formats in the database:
#               name
# 0          Alabama
# 1           Alaska
# 2          Arizona
# 3         Arkansas
# 4       California
# 5         Colorado
# 6      Connecticut
# 7         Delaware
# 8          Florida
# 9          Georgia
# 10          Hawaii
# 11           Idaho
# 12        Illinois
# 13         Indiana
# 14            Iowa
# 15          Kansas
# 16        Kentucky
# 17       Louisiana
# 18           Maine
# 19        Maryland
# 20   Massachusetts
# 21        Michigan
# 22       Minnesota
# 23     Mississippi
# 24        Missouri
# 25         Montana
# 26        Nebraska
# 27          Nevada
# 28   New Hampshire
# 29      New Jersey
# 30      New Mexico
# 31        New York
# 32  North Carolina
# 33    North Dakota
# 34            Ohio
# 35        Oklahoma
# 36          Oregon
# 37    Pennsylvania
# 38    Rhode Island
# 39  South Carolina
# 40    South Dakota
# 41       Tennessee
# 42           Texas
# 43            Utah
# 44         Vermont
# 45        Virginia
# 46      Washington
# 47   West Virginia
# 48       Wisconsin
# 49         Wyoming
#
#
# Looking for Texas with exact matching:
# Found: 'Texas'
# Testing different ways to query state names:
#
# Test 1: Double quotes
# Query: SELECT capital FROM states WHERE name = "Texas"
#   capital
# 0  Austin
#
# Test 2: Single quotes
# Query: SELECT capital FROM states WHERE name = 'Texas'
#   capital
# 0  Austin
#
# Test 3: Parameter binding
# Query: SELECT capital FROM states WHERE name = :state_name with params: {'state_name': 'Texas'}
#   capital
# 0  Austin
#
# Test 4: LIKE operator
# Query: SELECT capital FROM states WHERE name LIKE '%Texas%'
#   capital
# 0  Austin
#
# Test 5: Case insensitive comparison
# Query: SELECT capital FROM states WHERE LOWER(name) = LOWER('Texas')
#   capital
# 0  Austin
# Testing working queries:
#
# Population query:
# Query: SELECT name, population FROM states WHERE population > 10000000 ORDER BY population DESC
#              name  population
# 0      California    39536653
# 1           Texas    28304596
# 2         Florida    20984400
# 3        New York    19849399
# 4    Pennsylvania    12805537
# 5        Illinois    12802023
# 6            Ohio    11658609
# 7         Georgia    10429379
# 8  North Carolina    10273419
#
# Top 5 populous states:
# Query: SELECT name, population FROM states ORDER BY population DESC LIMIT 5
#            name  population
# 0    California    39536653
# 1         Texas    28304596
# 2       Florida    20984400
# 3      New York    19849399
# 4  Pennsylvania    12805537
#
# Largest states by area:
# Query: SELECT name, area_sq_miles FROM states ORDER BY area_sq_miles DESC LIMIT 5
# Error: (sqlite3.OperationalError) no such column: area_sq_miles
# [SQL: SELECT name, area_sq_miles FROM states ORDER BY area_sq_miles DESC LIMIT 5]
# (Background on this error at: https://sqlalche.me/e/20/e3q8)
#
# === RECOMMENDATIONS ===
# If all tests with state names failed, use this query function in your agent:
#
# def fixed_sql_query(query_str):
#     """Fix and execute SQL queries for states database"""
#     # Replace double quotes with single quotes for string literals
#     query_str = query_str.replace('"', ''')
#
#     # When using state names or text fields, use parameter binding
#     # Example:
#     # Instead of: SELECT * FROM states WHERE name = 'Texas'
#     # Use: SELECT * FROM states WHERE LOWER(name) = LOWER(:state_name)
#     # And pass parameters: {"state_name": "Texas"}
#
#     # For the agent integration, consider using text comparison functions
#     # to handle case sensitivity and possible formatting issues
#     return query_str

# %% [markdown]
# ## Test some queries

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT population FROM states WHERE name = 'Texas';"))
    print(result.fetchall())  # Expected output: [('Austin',)]
# Out:
# [(28304596,)]

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT capital FROM states WHERE name = 'California';"))
    print(result.fetchall())  # Expected output: [('Austin',)]
# Out:
# [('Sacramento',)]

# %%
with engine.connect() as conn:
    result = conn.execute(text("SELECT capital FROM states WHERE name = 'Texas'"))
    print(result.fetchall())  # Expected output: [('Austin',)]
# Out:
# [('Austin',)]

# %%
import sqlalchemy as sa
from sqlalchemy.orm import sessionmaker
from sqlalchemy import inspect
from dotenv import load_dotenv
import os
from IPython.display import display, Markdown
import asyncio
import re

from llama_index.core.query_engine import NLSQLTableQueryEngine
from llama_index.core import SQLDatabase, Settings
from llama_index.llms.google_genai import GoogleGenAI
from llama_index.indices.managed.llama_cloud import LlamaCloudIndex
from llama_index.core.tools import QueryEngineTool
from llama_index.core.agent import ReActAgent

# Load environment variables
load_dotenv()

# Initialize LLM
llm = GoogleGenAI(
    model="models/gemini-2.5-pro-exp-03-25",
    google_api_key=os.getenv("GOOGLE_API_KEY"),
    temperature=0.3
)
Settings.llm = llm

# Connect to the database
engine = sa.create_engine('sqlite:///states.db', future=True)
Session = sessionmaker(bind=engine)
session = Session()

# Get detailed table schema information
inspector = inspect(engine)
table_columns = {}
for table_name in inspector.get_table_names():
    columns = inspector.get_columns(table_name)
    table_columns[table_name] = [column['name'] for column in columns]

# Display available tables and columns for debugging
print("Available tables and columns:")
for table, columns in table_columns.items():
    print(f"Table: {table}")
    print(f"Columns: {', '.join(columns)}")
    print("-" * 80)

# Create the SQL database wrapper with explicit table info
sql_database = SQLDatabase(engine, include_tables=["states"])

# Generate sample data description to help the LLM understand the data structure
table_schema_str = """
Database Schema:
- states table:
  - object_id: Object ID like 
  - name: State name (e.g., "California", "Texas")
  - flag_url: link to states flag png image
  - link: url link to states page
  - postal_abbreviation: Two-letter state code (e.g., "CA", "TX")
  - capital: Capital city name
  - largest_city: name of largest city
  - established: date when state was established
  - population: state's population
  - total_area_square_miles= state total area in square miles
  - total_area_square_kilometers: total area in square kilometers
  - land_area_square_miles: land area in square miles
  - land_area_square_kilometers: land area in square kilometers
  - water_area_square_miles: water area in square miles
  - water_area_square_kilometers: water area in square kilometers
  - number_representatives: number of representatives
  - created_at: date of database creation
  - updated_at: date of database update
"""

# Create the natural language to SQL query engine with more context
sql_query_engine = NLSQLTableQueryEngine(
    sql_database=sql_database,
    tables=["states"],
    sample_rows_in_table_info=2,  # Include sample rows to provide better context
    llm=llm,
    embed_model=llm,
    synthesize_response=True,
    table_schema_str=table_schema_str,
    verbose=True  # This enables debug output to see the generated SQL
)

# Initialize the LlamaCloud index
index = LlamaCloudIndex(
    name="US-States-Wiki",
    project_name="sql_rag",
    organization_id="4134a95e-28e9-4996-8f81-c7ffebd05f99",
    api_key="llx-2U4S9cG2ii7YQFRsKOTkOmTtxJlMTnv8kHrpYzkT3gWJUEfK"
)

# Create a query engine for the `US-States-Wiki` index
llama_cloud_query_engine = index.as_query_engine()

# Create query tools around engines
sql_tool = QueryEngineTool.from_defaults(
    query_engine=sql_query_engine,
    description=(
        "Useful for answering factual questions about US states like population, "
        "capital, land size, postal abbreviation, and other demographic statistics "
        "stored in a structured database. The states table contains fields: "
        "name, abbreviation, capital, population, area_sq_miles, region, "
        "admitted_to_union, and median_household_income."
    ),
    name="sql_tool"
)

states = [
    "Alabama", "Alaska", "Arizona", "Arkansas", "California", "Colorado", 
    "Connecticut", "Delaware", "Florida", "Georgia (U.S. state)", "Hawaii", "Idaho", 
    "Illinois", "Indiana", "Iowa", "Kansas", "Kentucky", "Louisiana", 
    "Maine", "Maryland", "Massachusetts", "Michigan", "Minnesota", 
    "Mississippi", "Missouri", "Montana", "Nebraska", "Nevada", 
    "New Hampshire", "New Jersey", "New Mexico", "New York", 
    "North Carolina", "North Dakota", "Ohio", "Oklahoma", "Oregon", 
    "Pennsylvania", "Rhode Island", "South Carolina", "South Dakota", 
    "Tennessee", "Texas", "Utah", "Vermont", "Virginia", "Washington", 
    "West Virginia", "Wisconsin", "Wyoming"
]

llama_cloud_tool = QueryEngineTool.from_defaults(
    query_engine=llama_cloud_query_engine,
    description=(
        f"Useful for answering questions about US states' history, attractions, culture, "
        f"geography, and other information that requires searching through documents. "
        f"This tool contains Wikipedia information about all US states: {', '.join(states)}."
    ),
    name="llama_cloud_tool"
)

# Build the Agent with the tools
tools = [sql_tool, llama_cloud_tool]

agent = ReActAgent.from_tools(
    tools,
    llm=llm,
    verbose=True,
    system_prompt=(
        "You are an expert US States information system. "
        "You have access to two sources of information:\n\n"
        "1. A SQLite database with factual demographic data about US states in the 'states' table "
        "containing fields: object_id, name, flag_url, link, postal_abbreviation, capital, largest_city, "
        "established, population, total_area_square_miles, total_area_square_kilometers, land_area_square_miles, "
        "land_area_square_kilometers, water_area_square_miles, "
        "water_area_square_kilometers, number_representatives, created_at, updated_at\n\n"
        "2. Document retrieval for detailed information about history, attractions, and more\n\n"
        "Choose the appropriate tool based on the user's question. "
        "For the SQL tool, formulate clear SQL queries that match the database schema. "
        "Use the SQL tool for factual queries about population, area, capitals, etc. "
        "Use the document tool for questions about history, attractions, culture, and detailed information. "
        "If needed, you can use both tools and combine the information."
    )
)

# Function to clean SQL queries by removing unwanted prefixes like 'ite'
def clean_sql_query(query: str) -> str:
    """
    Fix malformed SQL queries by:
    - Removing unwanted prefixes (e.g., 'ite' or other incorrect text before SELECT)
    - Ensuring proper formatting before execution
    """
    query = query.strip()

    # Remove any leading non-SQL words (like 'ite' or unexpected characters)
    query = re.sub(r'^\s*\b\w+\b\s*', '', query, count=1)

    return query.strip()

# Function to handle user queries with better error handling
def answer_state_question(query):
    """
    Answer questions about US states using the appropriate tools.
    Args:
        query (str): User's natural language query 
    Returns:
        str: Response to the user's query
    """
    try:
        response = agent.query(query)
        
        # If the response contains an SQL error, attempt to clean the query
        if "error" in str(response).lower():
            print("🔄 Retrying after fixing SQL query...")

            # Extract the predicted SQL query (if available)
            extracted_query = response.metadata.get("sql_query", "")

            if extracted_query:
                fixed_query = clean_sql_query(extracted_query)
                return sql_query_engine.query(fixed_query)

        return response

    except Exception as e:
        print(f"⚠️ Error details: {str(e)}")
        
        try:
            # Direct SQL fallback if necessary
            if any(word in query.lower() for word in ['population', 'capital', 'area', 'largest']):
                print("🔄 Falling back to direct SQL query...")
                return sql_query_engine.query(clean_sql_query(query))
            else:
                print("🔄 Falling back to direct document query...")
                return llama_cloud_query_engine.query(query)
        except Exception as fallback_error:
            return f"❌ Sorry, I couldn't process your query. Error: {str(e)}\nFallback error: {str(fallback_error)}"

# Test queries focusing on SQL capabilities
if __name__ == "__main__":
    queries = [
        "What is the population of California?",
        "Which state has the largest land area?",
        "List the top 5 most populous states",
        "What is the capital of Texas?",
        "Which states have a population greater than 10 million?",
    ]
    
    for query in queries:
        print(f"\nQuestion: {query}")
        print(f"Answer: {answer_state_question(query)}")
        print("-" * 80)
# Out:
# Available tables and columns:
# Table: states
# Columns: id, object_id, name, flag_url, link, postal_abbreviation, capital, largest_city, established, population, total_area_square_miles, total_area_square_kilometers, land_area_square_miles, land_area_square_kilometers, water_area_square_miles, water_area_square_kilometers, number_representatives, created_at, updated_at, capitals_object_id
# --------------------------------------------------------------------------------
#
# Question: What is the population of California?
# > Running step ffe81ced-7743-4469-a93e-c43dbc5aee6b. Step input: What is the population of California?
# Thought: The user is asking for the population of California. This is a factual question about a US state statistic. The `sql_tool` is described as useful for answering factual questions about US states like population. I should use the `sql_tool` to get this information.
# Action: sql_tool
# Action Input: {'input': 'What is the population of California?'}
# > Table Info: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Table desc str: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Predicted SQL query: SELECT population FROM states WHERE name = 'California'
# Observation: The population of California is 39,536,653.
# > Running step a1c44bfc-8a81-421c-bb73-88daca5ccfc0. Step input: None
# Thought: I have the population of California from the `sql_tool`. I can now answer the user's question.
# Answer: The population of California is 39,536,653.
# Answer: The population of California is 39,536,653.
# --------------------------------------------------------------------------------
#
# Question: Which state has the largest land area?
# > Running step 1ceeaf11-03e3-4575-bd81-354683145a27. Step input: Which state has the largest land area?
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question about which US state has the largest land area. The `sql_tool` has access to state area information.
# Action: sql_tool
# Action Input: {'input': 'SELECT name FROM states ORDER BY area_sq_miles DESC LIMIT 1'}
# > Table Info: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Table desc str: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Predicted SQL query: SELECT name FROM states ORDER BY total_area_square_miles DESC LIMIT 1
# Observation: Alaska
# > Running step dd7e083b-4328-40ee-b2c5-10a03de496bc. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: Alaska has the largest land area.
# Answer: Alaska has the largest land area.
# --------------------------------------------------------------------------------
#
# Question: List the top 5 most populous states
# > Running step 087d54c2-01ea-49e2-a1a5-e7f8eade4f19. Step input: List the top 5 most populous states
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question. The `sql_tool` has access to population data for US states. I can query the database to get the top 5 most populous states.
# Action: sql_tool
# Action Input: {'input': 'SELECT name, population FROM states ORDER BY population DESC LIMIT 5;'}
# > Table Info: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Table desc str: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Predicted SQL query: SELECT name, population FROM states ORDER BY population DESC LIMIT 5;
# Observation: The 5 most populous states are:
# 1.  California with a population of 39,536,653.
# 2.  Texas with a population of 28,304,596.
# 3.  Florida with a population of 20,984,400.
# 4.  New York with a population of 19,849,399.
# 5.  Pennsylvania with a population of 12,805,537.
# > Running step 563592fc-98b4-409e-a0a9-8f86e6613f6c. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The top 5 most populous states are:
# 1.  California (39,536,653)
# 2.  Texas (28,304,596)
# 3.  Florida (20,984,400)
# 4.  New York (19,849,399)
# 5.  Pennsylvania (12,805,537)
# Answer: The top 5 most populous states are:
# 1.  California (39,536,653)
# 2.  Texas (28,304,596)
# 3.  Florida (20,984,400)
# 4.  New York (19,849,399)
# 5.  Pennsylvania (12,805,537)
# --------------------------------------------------------------------------------
#
# Question: What is the capital of Texas?
# > Running step f18f8c7d-7928-437f-bec8-3c45525d6a18. Step input: What is the capital of Texas?
# Thought: The current language of the user is: English. I need to use a tool to help me answer the question.
# Action: sql_tool
# Action Input: {'input': 'What is the capital of Texas?'}
# > Table Info: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Table desc str: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Predicted SQL query: SELECT capital FROM states WHERE name = 'Texas'
# Observation: The capital of Texas is Austin.
# > Running step 09fad8b6-e82a-4424-af3f-07d362be73b5. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The capital of Texas is Austin.
# Answer: The capital of Texas is Austin.
# --------------------------------------------------------------------------------
#
# Question: Which states have a population greater than 10 million?
# > Running step 064d8d50-9b15-4c65-ab56-814e4b1b030f. Step input: Which states have a population greater than 10 million?
# Thought: The current language of the user is: English. I need to use the `sql_tool` to query the database for states with a population greater than 10 million.
# Action: sql_tool
# Action Input: {'input': 'SELECT name FROM states WHERE population > 10000000'}
# > Table Info: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Table desc str: Table 'states' has columns: id (INTEGER), object_id (VARCHAR(50)), name (VARCHAR(50)), flag_url (VARCHAR(255)), link (VARCHAR(100)), postal_abbreviation (VARCHAR(2)), capital (VARCHAR(50)), largest_city (VARCHAR(50)), established (VARCHAR(50)), population (INTEGER), total_area_square_miles (INTEGER), total_area_square_kilometers (INTEGER), land_area_square_miles (INTEGER), land_area_square_kilometers (INTEGER), water_area_square_miles (INTEGER), water_area_square_kilometers (INTEGER), number_representatives (INTEGER), created_at (VARCHAR(100)), updated_at (VARCHAR(100)), capitals_object_id (VARCHAR(50)), .
# > Predicted SQL query: SELECT name FROM states WHERE population > 10000000
# Observation: The states with a population greater than 10,000,000 are California, Florida, Georgia, Illinois, New York, North Carolina, Ohio, Pennsylvania, and Texas.
# > Running step c6cb1fcb-a0ac-417b-8553-4a7968459483. Step input: None
# Thought: I can answer without using any more tools. I'll use the user's language to answer
# Answer: The states with a population greater than 10 million are California, Florida, Georgia, Illinois, New York, North Carolina, Ohio, Pennsylvania, and Texas.
# Answer: The states with a population greater than 10 million are California, Florida, Georgia, Illinois, New York, North Carolina, Ohio, Pennsylvania, and Texas.
# --------------------------------------------------------------------------------
